# %%
import pandas as pd

# %%
#criando DF
df_postos = pd.read_excel("raw_data/exportação.xlsx")

#checando colunas de lat long
df_postos[["LATITUDE","LONGITUDE"]]
# Out:
# c:\Users\ciror\AppData\Local\Programs\Python\Python312\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#              LATITUDE      LONGITUDE
# 0       -15:49:18,588  -48:06:47,465
# 1       -15:49:18,588  -48:06:47,465
# 2       -15:49:18,588  -48:06:47,465
# 3       -22:20:40,647  -49:03:46,018
# 4       -22:20:40,647  -49:03:46,018
# ...               ...            ...
# 183274            NaN            NaN
# 183275  -30:04:48,192  -51:01:24,279
# 183276  -30:04:48,192  -51:01:24,279
# 183277  -30:04:48,192  -51:01:24,279
# 183278  -30:04:48,192  -51:01:24,279
#
# [183279 rows x 2 columns]

# %%
def spliter_and_convert(df, coordinate_col, components):
    """
    Separa os valores de Graus, Minutos e Segundos da coluna de coordenada em colunas menores
    e converte as novas colunas em valor numérico
    """
    df[components] = df[coordinate_col].str.split(':', expand=True)
    df[components] = df[components].apply(pd.to_numeric, errors='coerce')
    return df

def convert_coordinate(df, degree_col, minute_col, second_col, result_col):
    """
    Converte os valores de Graus, Minutos e Segundos em Graus Decimais
    """
    if (df[degree_col] < 0).any():
        df[result_col] = df[degree_col] - ((df[minute_col] / 60) + df[second_col] / 3600)
    else:
        df[result_col] = df[degree_col] + ((df[minute_col] / 60) + df[second_col] / 3600)

def converter_latlong(df):
    """
    Centraliza a operação de conversão em uma única função,
    deleta as colunas obsoletas do DataFrame 
    e padroniza os nomes dos novos campos
    """
    spliter_and_convert(df, 'LATITUDE', ['latd', 'latm', 'lats'])
    convert_coordinate(df, 'latd', 'latm', 'lats', 'LATITUDE_FINAL')

    spliter_and_convert(df, 'LONGITUDE', ['lond', 'lonm', 'lons'])
    convert_coordinate(df, 'lond', 'lonm', 'lons', 'LONGITUDE_FINAL')

    df = df.drop(columns=['latd', 'latm', 'lats', 'lond', 'lonm', 'lons', 'LATITUDE', 'LONGITUDE'])
    df = df.rename(columns={"LATITUDE_FINAL": "LATITUDE", "LONGITUDE_FINAL": "LONGITUDE"})

    return df

# %%
#rodando a conversão
df_postos_conv = df_postos

# %%
#novas lat longs
#df_postos_conv[['latd', 'latm', 'lats']] = df_postos['LATITUDE'].str.split(':', expand=True)
df_postos_conv[['latd', 'latm', 'lats']] = df_postos_conv[['latd', 'latm', 'lats']].apply(pd.to_numeric, errors='coerce')
df_postos_conv
# Out:
#        Nº Autorizacao Data Publicação DOU - Autorização  \
# 0        PR/DF0012537                        04/01/2018
# 1        PR/DF0012537                        04/01/2018
# 2        PR/DF0012537                        04/01/2018
# 3        PR/SP0014189                        26/09/2001
# 4        PR/SP0014189                        26/09/2001
# ...               ...                               ...
# 183274   PR/RS0016627                        19/10/2001
# 183275   PR/RS0016982                        14/11/2001
# 183276   PR/RS0016982                        14/11/2001
# 183277   PR/RS0016982                        14/11/2001
# 183278   PR/RS0016982                        14/11/2001
#
#         Código Instalação i-Simp  \
# 0                        1000253
# 1                        1000253
# 2                        1000253
# 3                        1000254
# 4                        1000254
# ...                          ...
# 183274                   1029241
# 183275                   1029243
# 183276                   1029243
# 183277                   1029243
# 183278                   1029243
#
#                                              Razão Social            CNPJ  \
# 0                                           POSTO 81 LTDA      1974000190
# 1                                           POSTO 81 LTDA      1974000190
# 2                                           POSTO 81 LTDA      1974000190
# 3                      POSTO JARDIM AMERICA DE BAURU LTDA      2953000199
# 4                      POSTO JARDIM AMERICA DE BAURU LTDA      2953000199
# ...                                                   ...             ...
# 183274           COMERCIO DE COMBUSTIVEIS VIADUTENSE LTDA  98715121000114
# 183275  FIGUEIRA CENTRO COMERCIO E DERIVADOS DE COMBUS...  98749864000105
# 183276  FIGUEIRA CENTRO COMERCIO E DERIVADOS DE COMBUS...  98749864000105
# 183277  FIGUEIRA CENTRO COMERCIO E DERIVADOS DE COMBUS...  98749864000105
# 183278  FIGUEIRA CENTRO COMERCIO E DERIVADOS DE COMBUS...  98749864000105
#
#                                        Endereço COMPLEMENTO        BAIRRO  \
# 0                               LOC  CNN 2,  SN      LOTE A     CEILANDIA
# 1                               LOC  CNN 2,  SN      LOTE A     CEILANDIA
# 2                               LOC  CNN 2,  SN      LOTE A     CEILANDIA
# 3       AVENIDA NOSSA SENHORA DE FATIMA,  6 105         NaN  VILA AVIACAO
# 4       AVENIDA NOSSA SENHORA DE FATIMA,  6 105         NaN  VILA AVIACAO
# ...                                         ...         ...           ...
# 183274             RUA PADRE HENRIQUE KOCH,  14         NaN        CENTRO
# 183275               RUA BENTO GONCALVES,  1295         NaN        CENTRO
# 183276               RUA BENTO GONCALVES,  1295         NaN        CENTRO
# 183277               RUA BENTO GONCALVES,  1295         NaN        CENTRO
# 183278               RUA BENTO GONCALVES,  1295         NaN        CENTRO
#
#              CEP  UF MUNICÍPIO Vinculação a Distribuidor  \
# 0       72220500  DF  BRASILIA                     VIBRA
# 1       72220500  DF  BRASILIA                     VIBRA
# 2       72220500  DF  BRASILIA                     VIBRA
# 3       17053460  SP     BAURU                  IPIRANGA
# 4       17053460  SP     BAURU                  IPIRANGA
# ...          ...  ..       ...                       ...
# 183274  99820000  RS  VIADUTOS           BANDEIRA BRANCA
# 183275  94415700  RS    VIAMAO                    RAIZEN
# 183276  94415700  RS    VIAMAO                    RAIZEN
# 183277  94415700  RS    VIAMAO                    RAIZEN
# 183278  94415700  RS    VIAMAO                    RAIZEN
#
#        Data de Vinculação a Distribuidor                     Produto  \
# 0                             04/01/2018  GASOLINA C COMUM ADITIVADA
# 1                             04/01/2018  ETANOL HIDRATADO ADITIVADO
# 2                             04/01/2018            GASOLINA C COMUM
# 3                             04/11/2009            GASOLINA C COMUM
# 4                             04/11/2009  GASOLINA C COMUM ADITIVADA
# ...                                  ...                         ...
# 183274                        21/03/2018  ÓLEO DIESEL B S500 - COMUM
# 183275                        01/02/2019            GASOLINA C COMUM
# 183276                        01/02/2019  ÓLEO DIESEL B S500 - COMUM
# 183277                        01/02/2019   ÓLEO DIESEL B S10 - COMUM
# 183278                        01/02/2019  GASOLINA C COMUM ADITIVADA
#
#         Qtde de Bico       LATITUDE      LONGITUDE  latd  latm  lats
# 0                  4  -15:49:18,588  -48:06:47,465 -15.0  49.0   NaN
# 1                 12  -15:49:18,588  -48:06:47,465 -15.0  49.0   NaN
# 2                 12  -15:49:18,588  -48:06:47,465 -15.0  49.0   NaN
# 3                  4  -22:20:40,647  -49:03:46,018 -22.0  20.0   NaN
# 4                  2  -22:20:40,647  -49:03:46,018 -22.0  20.0   NaN
# ...              ...            ...            ...   ...   ...   ...
# 183274             1            NaN            NaN   NaN   NaN   NaN
# 183275             4  -30:04:48,192  -51:01:24,279 -30.0   4.0   NaN
# 183276             1  -30:04:48,192  -51:01:24,279 -30.0   4.0   NaN
# 183277             4  -30:04:48,192  -51:01:24,279 -30.0   4.0   NaN
# 183278             4  -30:04:48,192  -51:01:24,279 -30.0   4.0   NaN
#
# [183279 rows x 20 columns]
